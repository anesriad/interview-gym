# %% [markdown]
# # SQL Practice — Top spenders per city
#
# **Prompt:** For each city, find the **top 3 users by total completed-trip fare**. Return `city`, `user_id`, `total_fare`, and their rank within the city (1 = highest spender).
#
# Tables: `users`, `trips` (status `'completed'` has a fare). This is a classic window-function question — think about how to rank *within* a group.
#
# Solve in the cell below, then run `/review` in the chat. Try it solo first — running cells costs no tokens.

# %%
# Setup — run this first
# %load_ext sql
# %sql duckdb:///db/practice.db
# Out:
# RuntimeError: (_duckdb.IOException) IO Error: Cannot open file "/Users/riadanas/Desktop/Interview Prep Automation/problems/sql/db/practice.db": No such file or directory
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# -- Your query here
